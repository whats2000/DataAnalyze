# %% [markdown]
# # Car Datasets Description
#
# - **car_ID** - Unique ID of each observation (Integer)
# - **drivewheel** - Type of drive wheel (Categorical)
# - **wheelbase** - Wheelbase of the car (Numeric)
# - **enginesize** - Size of the car (Numeric)
# - **boreratio** - Boreratio of the car (Numeric)
# - **stroke** - Stroke or volume inside the engine (Numeric)
# - **compressionratio** - Compression ratio of the car (Numeric)
# - **horsepower** - Horsepower (Numeric)
# - **peakrpm** - Car peak rpm (Numeric)
# - **mpg** - Mileage (Numeric)
# - **PRICE** - Price of the car (Numeric)

# %% [markdown]
# ## Import Library and Load Data Set

# %%
# Import libraries
import pandas as pd

# %%
# Load the datasets
car_merge_A = pd.read_csv("Car_Merge_A.csv")
car_merge_B = pd.read_csv("Car_Merge_B.csv")
car_concat = pd.read_csv("Car_Concat.csv")

# %%
# Display the first few rows of each dataset to verify the data has been loaded correctly
print("Car_Merge_A dataset:")
car_merge_A.head()
# Out:
# Car_Merge_A dataset:
#    car_ID drivewheel  wheelbase
# 0       4        fwd       99.8
# 1       5        4wd       99.4
# 2       6        fwd       99.8
# 3       7        fwd      105.8
# 4       8        fwd      105.8

# %%
print("\nCar_Merge_B dataset:")
car_merge_B.head()
# Out:
# Car_Merge_B dataset:
#    car_ID  enginesize  boreratio  stroke  compressionratio  horsepower
# 0       4         109       3.19     3.4              10.0         102  \
# 1       5         136       3.19     3.4               8.0         115
# 2       6         136       3.19     3.4               8.5         110
# 3       7         136       3.19     3.4               8.5         110
# 4       8         136       3.19     3.4               8.5         110
#
#    peakrpm  mpg    PRICE
# 0     5500   54  13950.0
# 1     5500   40  17450.0
# 2     5500   44  15250.0
# 3     5500   44  17710.0
# 4     5500   44  18920.0

# %%
print("\nCar_Concat dataset:")
car_concat.head()
# Out:
# Car_Concat dataset:
#    car_ID drivewheel  wheelbase  enginesize  boreratio  stroke
# 0      38        fwd       96.5         110       3.15    3.58  \
# 1      39        fwd       96.5         110       3.15    3.58
# 2      40        fwd       96.5         110       3.15    3.58
# 3      41        fwd       96.5         110       3.15    3.58
# 4      42        fwd       96.5         110       3.15    3.58
#
#    compressionratio  horsepower  peakrpm  mpg    PRICE
# 0               9.0          86     5800   60   7895.0
# 1               9.0          86     5800   60   9095.0
# 2               9.0          86     5800   60   8845.0
# 3               9.0          86     5800   60  10295.0
# 4               9.0         101     5800   52  12945.0

# %% [markdown]
# ### 1.1. Perform an inner join on the "Car_Merge_A'' and "Car_Merge_B" datasets
#
# - Using "car_ID" as the primary key.
# - Then, concatenate the merged dataset with the "Car_Concat" dataset along the row axis.
# - Convert any character columns to a factor in R and categorical in Pythons.
#
# *Note that the remaining 'car_ID' is not one of our variables, delete it or convert it into the index.*

# %%
# Inner join "Car_Merge_A" and "Car_Merge_B" datasets using "car_ID" as the primary key
merged_AB = pd.merge(car_merge_A, car_merge_B, on="car_ID")
merged_AB.head()
# Out:
#    car_ID drivewheel  wheelbase  enginesize  boreratio  stroke
# 0       4        fwd       99.8         109       3.19     3.4  \
# 1       5        4wd       99.4         136       3.19     3.4
# 2       6        fwd       99.8         136       3.19     3.4
# 3       7        fwd      105.8         136       3.19     3.4
# 4       8        fwd      105.8         136       3.19     3.4
#
#    compressionratio  horsepower  peakrpm  mpg    PRICE
# 0              10.0         102     5500   54  13950.0
# 1               8.0         115     5500   40  17450.0
# 2               8.5         110     5500   44  15250.0
# 3               8.5         110     5500   44  17710.0
# 4               8.5         110     5500   44  18920.0

# %%
# Concatenate the merged dataset with "Car_Concat" along the row axis
final_dataset = pd.concat([merged_AB, car_concat])
final_dataset
# Out:
#     car_ID drivewheel  wheelbase  enginesize  boreratio  stroke
# 0        4        fwd       99.8         109       3.19    3.40  \
# 1        5        4wd       99.4         136       3.19    3.40
# 2        6        fwd       99.8         136       3.19    3.40
# 3        7        fwd      105.8         136       3.19    3.40
# 4        8        fwd      105.8         136       3.19    3.40
# ..     ...        ...        ...         ...        ...     ...
# 95     199        rwd      104.3         130       3.62    3.15
# 96     200        rwd      104.3         130       3.62    3.15
# 97     201        rwd      109.1         141       3.78    3.15
# 98     202        rwd      109.1         141       3.78    3.15
# 99     205        rwd      109.1         141       3.78    3.15
#
#     compressionratio  horsepower  peakrpm  mpg    PRICE
# 0               10.0         102     5500   54  13950.0
# 1                8.0         115     5500   40  17450.0
# ...

# %%
# Check data types
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            133 non-null    int64
#  1   drivewheel        133 non-null    object
#  2   wheelbase         133 non-null    float64
#  3   enginesize        133 non-null    int64
#  4   boreratio         133 non-null    float64
#  5   stroke            133 non-null    float64
#  6   compressionratio  133 non-null    float64
#  7   horsepower        133 non-null    int64
#  8   peakrpm           133 non-null    int64
#  9   mpg               133 non-null    int64
#  10  PRICE             133 non-null    float64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 12.5+ KB

# %%
# Convert any character columns to categorical in Python
final_dataset["drivewheel"] = final_dataset["drivewheel"].astype('category')
final_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 133 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            133 non-null    int64
#  1   drivewheel        133 non-null    category
#  2   wheelbase         133 non-null    float64
#  3   enginesize        133 non-null    int64
#  4   boreratio         133 non-null    float64
#  5   stroke            133 non-null    float64
#  6   compressionratio  133 non-null    float64
#  7   horsepower        133 non-null    int64
#  8   peakrpm           133 non-null    int64
#  9   mpg               133 non-null    int64
#  10  PRICE             133 non-null    float64
# dtypes: category(1), float64(5), int64(5)
# memory usage: 11.7 KB

# %%
# To drop "car_ID":
final_dataset.drop("car_ID", axis=1, inplace=True)

# Display the first few rows of the final dataset to verify the changes
final_dataset.head()
# Out:
#   drivewheel  wheelbase  enginesize  boreratio  stroke  compressionratio
# 0        fwd       99.8         109       3.19     3.4              10.0  \
# 1        4wd       99.4         136       3.19     3.4               8.0
# 2        fwd       99.8         136       3.19     3.4               8.5
# 3        fwd      105.8         136       3.19     3.4               8.5
# 4        fwd      105.8         136       3.19     3.4               8.5
#
#    horsepower  peakrpm  mpg    PRICE
# 0         102     5500   54  13950.0
# 1         115     5500   40  17450.0
# 2         110     5500   44  15250.0
# 3         110     5500   44  17710.0
# 4         110     5500   44  18920.0

# %% [markdown]
# ### 1.2. Data Exploration
#
# - For continuous variables, create density plots to understand the distribution of the data.
# - For categorical/factor variables, generate frequency tables and bar charts to summarize the counts of each category.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select continuous variables
continuous_vars = ['wheelbase', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'mpg', 'PRICE']

# Create a 3x3 grid of subplots
fig, axes = plt.subplots(3, 3, figsize=(15, 12))

# Flatten the axe array
axes = axes.ravel()

# Define a list of colors for the plots
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown', 'pink', 'gray', 'cyan']

# Create density plots for continuous variables with different colors using list comprehension
[ sns.kdeplot(data=final_dataset[var], ax=axes[i], color=colors[i], fill=True) for i, var in enumerate(continuous_vars) ]

# Set titles for each subplot
[ axes[i].set_title(f'Density Plot - {var}') for i, var in enumerate(continuous_vars) ]

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Select a categorical variable to summarize
categorical_var = 'drivewheel'

# Generate a frequency table for the selected categorical variable
frequency_table = final_dataset[categorical_var].value_counts()

# Create a bar chart to visualize the frequency of categories
plt.figure(figsize=(8, 6))
sns.barplot(x=frequency_table.index, y=frequency_table.values, palette='viridis')
plt.title(f'Frequency of {categorical_var} Categories')
plt.xlabel(f'{categorical_var} Category')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 1.3. Consider doing a series of bivariate analyses on "PRICE vs. the rest of variables."
#
# Specifically, plot your data and perform bivariate statistical tests to understand the relationships among the variables

# %%
continuous_vars = ['wheelbase', 'enginesize', 'boreratio', 'stroke', 'compressionratio', 'horsepower', 'peakrpm', 'mpg', 'PRICE']

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

def plot_bivariate_analyses(current_index: int, min_x: float=-1, max_x: float=-1, min_y: float=-1, max_y: float=-1, use_log_x: bool=False, use_log_y: bool=False) -> None:
    """
    Create a scatter plot with a regression line and calculate Pearson correlation coefficients.

    Parameters:
    - current_index (int): Index of the continuous variable to be plotted against 'PRICE'.
    - min_x (float, optional): Minimum value for the x-axis (default is -1, auto-scale).
    - max_x (float, optional): Maximum value for the x-axis (default is -1, auto-scale).
    - min_y (float, optional): Minimum value for the y-axis (default is -1, auto-scale).
    - max_y (float, optional): Maximum value for the y-axis (default is -1, auto-scale).
    - use_log_x (bool, optional): Set to True to apply logarithmic scale to the x-axis (default is False).
    - use_log_y (bool, optional): Set to True to apply logarithmic scale to the y-axis (default is False).

    This function creates a scatter plot of the selected continuous variable against 'PRICE'. It also adds a regression line
    to visualize the linear relationship between the variables. The y-axis is inverted to have the origin at the bottom.
    Optional parameters allow for custom axis limits and logarithmic scaling.

    After plotting, the function calculates the Pearson correlation coefficient and p-value to quantify the linear
    relationship between the variables and displays them.

    Example usage:
    plot_bivariate_analyses(0) # Plot the first continuous variable against 'PRICE'.

    """
    # Create a scatter plot for the selected continuous variable vs. 'PRICE'
    plt.figure(figsize=(8, 6))
    ax = sns.scatterplot(data=final_dataset, x=continuous_vars[current_index], y='PRICE', color='blue')

    # Add a regression line to visualize the linear relationship
    sns.regplot(data=final_dataset, x=continuous_vars[current_index], y='PRICE', scatter=False, ax=ax, color='red')

    # Invert the y-axis to have the origin at the bottom
    ax.invert_yaxis()

    # Set the title and axis labels
    plt.title(f'Scatter Plot: {continuous_vars[current_index]} vs. PRICE')
    plt.xlabel(f'{continuous_vars[current_index]}')
    plt.ylabel('PRICE')

    # Set optional limits for the x and y axes
    if min_x != -1 and max_x != -1:
        plt.xlim(min_x, max_x)

    if min_y != -1 and max_y != -1:
        plt.ylim(min_y, max_y)

    # Apply logarithmic scale to the x and/or y-axis if specified
    if use_log_x:
        plt.xscale('log')

    if use_log_y:
        plt.yscale('log')

    # Display the plot
    plt.show()

    # Calculate the Pearson correlation coefficient and p-value
    correlation, p_value = pearsonr(final_dataset[continuous_vars[current_index]], final_dataset['PRICE'])

    # Display the correlation coefficient and p-value
    print(f"Pearson Correlation Coefficient: {correlation:.2f}")
    print(f"P-Value: {p_value:.8f}")

# %%
# Wheelbase VS Price
plot_bivariate_analyses(0, 92, 110, 5000, 25000)
# Out:
# Pearson Correlation Coefficient: 0.72
# P-Value: 0.00000000

# %%
# Enginesize VS Price
plot_bivariate_analyses(1, 80, 180, 5000, 25000)
# Out:
# Pearson Correlation Coefficient: 0.84
# P-Value: 0.00000000

# %%
# Boreratio VS Price
plot_bivariate_analyses(2, 2.9, 3.8, 5000, 20000)
# Out:
# Pearson Correlation Coefficient: 0.58
# P-Value: 0.00000000

# %%
# Stroke VS Price
plot_bivariate_analyses(3, 3, 4, 5000, 25000)
# Out:
# Pearson Correlation Coefficient: 0.01
# P-Value: 0.88721370

# %%
# Compressionratio VS Price
plot_bivariate_analyses(4, 6.75, 10, 5000, 25000)
# Out:
# Pearson Correlation Coefficient: -0.32
# P-Value: 0.00019131

# %%
# Horsepower VS Price
plot_bivariate_analyses(5, 50, 130, 5000, 25000)
# Out:
# Pearson Correlation Coefficient: 0.82
# P-Value: 0.00000000

# %%
# Peakrpm VS Price
plot_bivariate_analyses(6, 4000, 6100, 5000, 25000)
# Out:
# Pearson Correlation Coefficient: -0.01
# P-Value: 0.91293922

# %%
# Mpg VS Price
plot_bivariate_analyses(7, 35, 80, 5000, 25000)
# Out:
# Pearson Correlation Coefficient: -0.73
# P-Value: 0.00000000

# %%
# Create a box plot or violin plot to visualize the distribution of 'PRICE' for each 'drivewheel' category
plt.figure(figsize=(10, 6))
sns.boxplot(data=final_dataset, x='drivewheel', y='PRICE', palette='viridis')
plt.title('Bivariate Analysis: Drivewheel vs. Price')
plt.xlabel('Drivewheel')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.show()

# Calculate summary statistics (mean, median, etc.) for 'PRICE' within each 'drivewheel' category
summary_stats = final_dataset.groupby('drivewheel')['PRICE'].describe()

# Display the summary statistics
print("Summary Statistics for 'PRICE' by Drive-wheel Category:")
summary_stats
# Out:
# Summary Statistics for 'PRICE' by Drive-wheel Category:
#             count          mean          std     min      25%      50%
# drivewheel
# 4wd           4.0  12996.291750  5393.503405  7898.0   8558.0  13114.0  \
# fwd          98.0   9054.265306  3192.577249  5195.0   6850.5   8222.0
# rwd          31.0  17286.387097  7994.689440  6785.0  11374.0  16515.0
#
#                     75%        max
# drivewheel
# 4wd         17552.29175  17859.167
# fwd          9993.25000  23875.000
# rwd         20007.50000  41315.000

# %% [markdown]
# ### 1.4. Please perform normality tests on PRICE.
# - Does it seem "normal?"
# - If not, do you think fitting general linear models to predict or explain the outcome is appropriate?

# %%
import matplotlib.pyplot as plt
from scipy.stats import shapiro, probplot

# Extract the PRICE column
price_data = final_dataset['PRICE']

# Perform Shapiro-Wilk normality test
stat, p = shapiro(price_data)

# Interpret the results
alpha = 0.05
if p > alpha:
    print("PRICE is normally distributed (p =", p, ")")
else:
    print("PRICE is not normally distributed (p =", p, ")")

# Visualize the data using a histogram and Q-Q plot
plt.figure(figsize=(12, 5))

# Histogram
plt.subplot(1, 2, 1)  # Creating a subplot, one row, two columns, first plot
plt.hist(price_data, bins=20, color='blue', alpha=0.7)  # Creating a histogram
plt.title('Histogram of PRICE')  # Adding a title to the histogram
plt.xlabel('Price')  # Labeling the x-axis
plt.ylabel('Frequency')  # Labeling the y-axis

# Q-Q plot
plt.subplot(1, 2, 2)  # Creating the second plot
probplot(price_data, plot=plt)  # Creating a Q-Q plot
plt.title('Q-Q Plot of PRICE')  # Adding a title to the Q-Q plot

plt.tight_layout()  # Ensuring proper spacing between subplots
plt.show()  # Displaying the plots
# Out:
# PRICE is not normally distributed (p = 4.253441674394176e-13 )

# %% [markdown]
# ### 1.5. Consider fitting linear models with manually selected variables (i.e., multivariate analysis).
# - What is your best model?
# - You may consider those variables with "p < 0.05".

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# Set a random seed
random_seed = 20230929

# Specify the features (X) and the target variable (y)
X = final_dataset.drop(columns=['PRICE'])  # Features
y = final_dataset['PRICE']  # Target variable

# Perform one-hot encoding for categorical variables
X_encoded = pd.get_dummies(X, columns=['drivewheel'], drop_first=True)

# Split the dataset into a 70% training set and a 30% testing set
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.30, random_state=random_seed)

# Print the shapes of the training and testing sets to verify the split
print("Training set shape (X, y):", X_train.shape, y_train.shape)
print("Testing set shape (X, y):", X_test.shape, y_test.shape)
# Out:
# Training set shape (X, y): (93, 10) (93,)
# Testing set shape (X, y): (40, 10) (40,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Create a LinearRegression model
model = LinearRegression()

# Manually select the predictor variables
selected_features = ['wheelbase', 'enginesize', 'stroke', 'compressionratio', 'horsepower', 'peakrpm']

# Extract the selected features from the training and testing sets
X_train_selected = X_train[selected_features]
X_test_selected = X_test[selected_features]

# Fit the model to the training data using the selected features
model.fit(X_train_selected, y_train)

# Make predictions on the training data
y_train_pred = model.predict(X_train_selected)

# Make predictions on the testing data
y_test_pred = model.predict(X_test_selected)

# Evaluate the model's performance on the training data
train_mse = mean_squared_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

# Evaluate the model's performance on the testing data
test_mse = mean_squared_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Store the result
model_result = {"manually selected linear model": {"train": y_train_pred, "test": y_test_pred}}

# Print the model's performance metrics
print("Training MSE:", train_mse)
print("Training R-squared:", train_r2)
print("\nTesting MSE:", test_mse)
print("Testing R-squared:", test_r2)
# Out:
# Training MSE: 5566183.539484551
# Training R-squared: 0.8683035720008123
#
# Testing MSE: 4949426.8151938105
# Testing R-squared: 0.640320080779468

# %% [markdown]
# ### 1.6. Split the Car dataset into 70% training and 30% testing sets
# - Using random seed “20230929.”
# - Using the training set, build multiple linear regression models with the predictor variables selected in previous analyses.

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# Set a random seed
random_seed = 20230929

# Specify the features (X) and the target variable (y)
X = final_dataset.drop(columns=['PRICE'])  # Features
y = final_dataset['PRICE']  # Target variable

# Perform one-hot encoding for categorical variables
X_encoded = pd.get_dummies(X, columns=['drivewheel'], drop_first=True)

# Split the dataset into a 70% training set and a 30% testing set
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.30, random_state=random_seed)

# Print the shapes of the training and testing sets to verify the split
print("Training set shape (X, y):", X_train.shape, y_train.shape)
print("Testing set shape (X, y):", X_test.shape, y_test.shape)
# Out:
# Training set shape (X, y): (93, 10) (93,)
# Testing set shape (X, y): (40, 10) (40,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Create a LinearRegression model
model = LinearRegression()

# Fit the model to the training data
model.fit(X_train, y_train)

# Make predictions on the training data
y_train_pred = model.predict(X_train)

# Make predictions on the testing data
y_test_pred = model.predict(X_test)

# Evaluate the model's performance on the training data
train_mse = mean_squared_error(y_train, y_train_pred)
train_r2 = r2_score(y_train, y_train_pred)

# Evaluate the model's performance on the testing data
test_mse = mean_squared_error(y_test, y_test_pred)
test_r2 = r2_score(y_test, y_test_pred)

# Store the result
model_result["all selected linear model"] = {"train": y_train_pred, "test": y_test_pred}

# Print the model's performance metrics
print("Training MSE:", train_mse)
print("Training R-squared:", train_r2)
print("\nTesting MSE:", test_mse)
print("Testing R-squared:", test_r2)
# Out:
# Training MSE: 3742498.0815368732
# Training R-squared: 0.9114521420941393
#
# Testing MSE: 10742239.777622573
# Testing R-squared: 0.2193504258711675

# %% [markdown]
# ### 1.7. Computes Root Mean Square Error (RMSE), which is defined as:
# ![Root Mean Square Error](RootMeanSquareError.png)
#
# - where and are actual and predicted values, respectively.
# - Then apply your linear models to the training and testing sets, train_d and test_d.
# - What are the RMSEs of your models?
# - What is your best model in terms of accuracy of prediction (with lowest RMSE)?

# %%
#Define a function to calculate RMSE (Root Mean Square Error)
import numpy as np
from typing import Union

def calculate_root_mean_square_error(actual: Union[list, np.ndarray], predicted: Union[list, np.ndarray]) -> float:
    """
    Calculate the Root Mean Square Error (RMSE) between actual and predicted values.

    Parameters:
    - actual (list or np.ndarray): The actual target values.
    - predicted (list or np.ndarray): The predicted target values.

    Returns:
    - rmse (float): The Root Mean Square Error.
    """
    # Convert input lists/arrays to numpy arrays to ensure compatibility
    actual = np.array(actual)
    predicted = np.array(predicted)

    # Calculate the squared differences between actual and predicted values
    squared_errors = (actual - predicted) ** 2

    # Calculate the mean of squared errors
    mse = squared_errors.mean()

    # Calculate the square root of the mean squared error to get RMSE
    return np.sqrt(mse)

# %%
# Evaluate the model's performance on the training data
train_rmse_1 = calculate_root_mean_square_error(y_train, model_result["manually selected linear model"]["train"])

# Evaluate the model's performance on the testing data
test_rmse_1 = calculate_root_mean_square_error(y_test, model_result["manually selected linear model"]["test"])

# Print the model's performance metrics
print("Training RMSE:", train_rmse_1)
print("\nTesting RMSE:", test_rmse_1)
# Out:
# Training RMSE: 2359.27606258457
#
# Testing RMSE: 2224.730728693657

# %%
# Evaluate the model's performance on the training data
train_rmse_2 = calculate_root_mean_square_error(y_train, model_result["all selected linear model"]["train"])

# Evaluate the model's performance on the testing data
test_rmse_2 = calculate_root_mean_square_error(y_test, model_result["all selected linear model"]["test"])

# Print the model's performance metrics
print("Training RMSE:", train_rmse_2)
print("\nTesting RMSE:", test_rmse_2)
# Out:
# Training RMSE: 1934.553716374108
#
# Testing RMSE: 3277.535625683201

# %%
# Create a dictionary with the model results
model_results = {
    "Model": ["Manually Selected Linear Model", "All Selected Linear Model"],
    "Training RMSE": [train_rmse_1, train_rmse_2],
    "Testing RMSE": [test_rmse_1, test_rmse_2]
}

# Create a DataFrame from the dictionary
results_df = pd.DataFrame(model_results)

# Display the results table
results_df
# Out:
#                             Model  Training RMSE  Testing RMSE
# 0  Manually Selected Linear Model    2359.276063   2224.730729
# 1       All Selected Linear Model    1934.553716   3277.535626

# %% [markdown]
# ### 1.8. Run summary() to get more information about your linear models
# - Report the variables with p-value < 0.05.
# - Also run any correlation tests and report the variables with high correlations.
# - Do you think the correlation coefficient is a good measurement for variable importance ranking?

# %%
import pandas as pd
from scipy.stats import pearsonr

columns_to_check = [
    'wheelbase', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
    'horsepower', 'peakrpm', 'mpg', 'drivewheel_fwd', 'drivewheel_rwd'
]

correlation_results = {column: pearsonr(X_train[column], y_train) for column in columns_to_check}

# Extract the statistic and pvalue from the PearsonRResult and create a DataFrame
correlation_df = pd.DataFrame(
    [{'Variable': column, 'Correlation_Statistic': result[0], 'Correlation_PValue': result[1]} for column, result in correlation_results.items()]
)

# Print the DataFrame
correlation_df.sort_values('Correlation_PValue')
# Out:
#            Variable  Correlation_Statistic  Correlation_PValue
# 1        enginesize               0.875366        1.796557e-30
# 5        horsepower               0.842592        3.431630e-26
# 0         wheelbase               0.734393        5.439193e-17
# 7               mpg              -0.732877        6.784858e-17
# 8    drivewheel_fwd              -0.633808        9.161571e-12
# 9    drivewheel_rwd               0.622524        2.704798e-11
# 2         boreratio               0.588697        5.428155e-10
# 4  compressionratio              -0.320096        1.760756e-03
# 3            stroke              -0.040994        6.964282e-01
# 6           peakrpm              -0.010873        9.176111e-01

# %% [markdown]
# - I believe it can be done.
# - By comparing these correlation coefficients, we can assess the significance of p-values and the values of various statistics.
# - We can observe which variables have higher significance. In this dataset, variables with a p-value < 0.05 are highly significant.
# - Therefore, when determining the ranking of variable importance, correlation coefficients are a good measurement.
